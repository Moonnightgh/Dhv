# %% [markdown]
# <a href="https://colab.research.google.com/github/Moonnightgh/Dhv/blob/main/heatmaps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data=np.random.random((13,16))
plt.imshow(data,cmap="magma")
plt.title("2D heat map")
plt.colorbar()
plt.show()

# %%
import seaborn as sns
data=np.random.randint(low=14,high=100,size=(20,20))
hm=sns.heatmap(data=data,annot=True)

plt.show()
